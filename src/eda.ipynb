# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook explores the Sri Lanka tourism dataset (2015–2024).
# - Tourist arrivals
# - Tourism revenue
# - Average stay
# - Average daily spend

# %%
# %pip install seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("../data/raw/tourism_data.csv")
df.head()
# Out:
#    year  month  tourist_arrivals  tourism_revenue_usd  avg_stay  \
# 0  2015      1            155000            255000000      10.0
# 1  2015      2            160000            265000000      10.0
# 2  2015      3            170000            280000000      10.2
# 3  2015      4            140000            230000000       9.8
# 4  2015      5            130000            210000000       9.5
#
#    avg_daily_spend
# 0              165
# 1              165
# 2              166
# 3              164
# 4              163

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 120 non-null    int64
#  1   month                120 non-null    int64
#  2   tourist_arrivals     120 non-null    int64
#  3   tourism_revenue_usd  120 non-null    int64
#  4   avg_stay             120 non-null    float64
#  5   avg_daily_spend      120 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 5.8 KB

# %% [markdown]
# ### 📈 1. Line plot of arrivals & revenue over time

# %%
import matplotlib.pyplot as plt

# Create a date column for plotting
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'].astype(str) + '-01')

plt.figure(figsize=(12,6))
plt.plot(df['date'], df['tourist_arrivals']/1000, label="Tourist Arrivals (in thousands)")
plt.plot(df['date'], df['tourism_revenue_usd']/1e6, label="Tourism Revenue (in million USD)")
plt.title("Tourist Arrivals & Revenue Over Time (2015–2024)")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### 📊 2. Histogram of average daily spend

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['avg_daily_spend'], bins=20, kde=True, color="skyblue")
plt.title("Distribution of Average Daily Spend")
plt.xlabel("Average Daily Spend (USD)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 📦 3. Boxplot of average stay by year

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="year", y="avg_stay", data=df, palette="Set2")
plt.title("Distribution of Average Stay Duration by Year")
plt.xlabel("Year")
plt.ylabel("Average Stay (days)")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\nimes\AppData\Local\Temp\ipykernel_5336\1902552386.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="year", y="avg_stay", data=df, palette="Set2")
